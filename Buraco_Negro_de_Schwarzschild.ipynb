# %% [markdown]
# # TCC "Métrica de Buracos Negros: Singularidade, Horizonte de Eventos e Ergosfera"
# ## Larissa Degen de Almeida
# ## Figuras da Métrica de Schwarzschild
# ### Versão de 01/10/2021

# %%
from sympy import *
from sympy.plotting.plot import plot_parametric

# %%
def figura_Schwarzschild(M):
    theta = Symbol('theta')
    r_hor = 2*M
    plot_parametric((r_hor*sin(theta), r_hor*cos(theta)), (theta, 0, 2*pi), aspect_ratio=(1, 1), 
                    xlim=[-10, 10], ylim=[-10, 10], xlabel="x", ylabel="z", line_color = 'blue',
                    legend=True, label='hor', title="Schwarzschild, M={}\n".format(M), size=(6, 6))

# %%
figura_Schwarzschild(4.2)

# %%
figura_Schwarzschild(2.1)
